# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/sundeepk/Desktop/uber.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# ...

# %%
df.tail()
# Out:
#         Unnamed: 0                           key  fare_amount  \
# 199995    42598914 2012-10-28 10:49:00.000000530          3.0
# 199996    16382965 2014-03-14 01:09:00.000000800          7.5
# 199997    27804658 2009-06-29 00:42:00.000000780         30.9
# 199998    20259894 2015-05-20 14:56:25.000000400         14.5
# 199999    11951496 2010-05-15 04:08:00.000000760         14.1
#
#                  pickup_datetime  pickup_longitude  pickup_latitude  \
# 199995 2012-10-28 10:49:00+00:00        -73.987042        40.739367
# 199996 2014-03-14 01:09:00+00:00        -73.984722        40.736837
# 199997 2009-06-29 00:42:00+00:00        -73.986017        40.756487
# 199998 2015-05-20 14:56:25+00:00        -73.997124        40.725452
# 199999 2010-05-15 04:08:00+00:00        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 199995         -73.986525         40.740297                1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
#CONVERT THE COLUMNS TO DATETIME

df['key']= pd.to_datetime(df['key'])

df['pickup_datetime']= pd.to_datetime(df['pickup_datetime'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  datetime64[ns]
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  datetime64[ns, UTC]
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: datetime64[ns, UTC](1), datetime64[ns](1), float64(5), int64(2)
# memory usage: 13.7 MB

# %%
df['pickup_datetime'] =pd.to_datetime(df['pickup_datetime'])

# %%
#DROP THE DUPLICATES
df = df.drop_duplicates().reset_index(drop=True)

#CREATE COLUMN 
df['trip_id']=df.index

# %%
df.head()
# Out:
#    Unnamed: 0                           key  fare_amount  \
# 0    24238194 2015-05-07 19:52:06.000000300          7.5
# 1    27835199 2009-07-17 20:04:56.000000200          7.7
# 2    44984355 2009-08-24 21:45:00.000000610         12.9
# 3    25894730 2009-06-26 08:22:21.000000100          5.3
# 4    17610152 2014-08-28 17:47:00.000000188         16.0
#
#             pickup_datetime  pickup_longitude  pickup_latitude  \
# 0 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2 2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4 2014-08-28 17:47:00+00:00        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count  trip_id
# 0         -73.999512         40.723217                1        0
# 1         -73.994710         40.750325                1        1
# ...

# %%
# Extract the date and time components
df['pickup_date'] = df['pickup_datetime'].dt.date
df['pickup_hour'] = df['pickup_datetime'].dt.hour
df['pickup_day'] = df['pickup_datetime'].dt.day
df['pickup_month'] = df['pickup_datetime'].dt.month
df['pickup_year'] = df['pickup_datetime'].dt.year

# Create the 'datetime_id' column (no need to set it as the index again)
df['datetime_id'] = df.index

# Select the desired columns in the 'datetime' DataFrame
datetime = df[['datetime_id', 'pickup_datetime', 'pickup_hour', 'pickup_day', 'pickup_month', 'pickup_year']]

# Display the first few rows of 'datetime'
datetime.head()


xxxxxxx
yyyyyyy
# Out:
#    datetime_id           pickup_datetime  pickup_hour  pickup_day  \
# 0            0 2015-05-07 19:52:06+00:00           19           7
# 1            1 2009-07-17 20:04:56+00:00           20          17
# 2            2 2009-08-24 21:45:00+00:00           21          24
# 3            3 2009-06-26 08:22:21+00:00            8          26
# 4            4 2014-08-28 17:47:00+00:00           17          28
#
#    pickup_month  pickup_year
# 0             5         2015
# 1             7         2009
# 2             8         2009
# 3             6         2009
# 4             8         2014
